# %% [markdown]
# # Testing

# %% [markdown]
# This is a test for the organic-imgrec package.

# %%
import organic
import organic._consts

organic.dummy()
# Out:
# You're a dummy!

# %%
print(f"Oh no maaan: {organic._consts.MAS2RAD}.\nThat shit ain't good.")
# Out:
# Oh no maaan: 4.84813681109536e-09.
# That shit ain't good.

# %% [markdown]
# #
